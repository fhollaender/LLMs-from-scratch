# %%
import pandas as pd
from transformers import AutoTokenizer, AutoModel
import torch



df = pd.read_csv('../../datasets/gekuerzt_bereinigt.csv', dtype=str)
print(df.head(10))
print('Alle SPalten', df.columns.tolist())

#▪ Concretely, implement and analyze:
#▪ Tokenizer (with “unknown” and “endoftext” handling)
#▪ BPE
#▪ Data sampling - try different context sizes and strides
#▪ Put it together (token embeddings) and integrate positional embeddings
# Out:
#   Unnamed: 0                                              title  \
# 0    2131142                     Vegetable Frittata with Cheese
# 1    2131143  Grilled Clams with Spaghetti, Prosciutto, and ...
# 2    2131144                          Spiced up Vegetable Pasta
# 3    2131145           Secret Ingredient Chocolate Chip Cookies
# 4    2131146                       Chantri's Poppy Seed Chicken
# 5    2131147                            Southwestern Rice Salad
# 6    2131148                                        Quesadillas
# 7    2131149  Roasted Tomato and Shallot Salad with Goat Cheese
# 8    2131150                Mixed Grain Sour Dough Bread Recipe
# 9    2131151                              Italian Cheeseburgers
#
#                                          ingredients  \
# 0  ["8 large eggs slightly beaten", "1 tablespoon...
# 1  ["1/2 cup extra-virgin olive oil", "4 garlic c...
# 2  ["14 cup bell pepper, finely chopped (yellow, ...
# 3  ["12 cup butter", "12 cup butter flavor shorte...
# 4  ["4 chicken breasts", "1 can cream of mushroom...
# 5  ["3-3/4 qt. cooked long-grain white rice", "3-...
# 6  ["1 cup canned refried beans", "2 large flour ...
# 7  ["8 small shallots, quartered", "1 1/2 cups gr...
# 8  ["3 1/2 c. hot stock or possibly water", "2 tb...
# 9  ["12 lb ground beef", "12 lb ground hot Italia...
#
#                                           directions  \
# 0  ["In a medium bowl combine eggs and basil; set...
# 1  ["Heat oil in heavy large pot over medium-high...
# 2  ["Bring a large pot of salted water to a rolli...
# 3  ["Soften butter and shortening in microwave.",...
# 4  ["Preheat oven to 350*.", "Poach chicken until...
# 5                       ["Combine all ingredients."]
# 6  ["Preheat oven to 350 degrees.", "Spread beans...
# 7  ["Preheat the oven to 350.", "In a medium baki...
# 8  ["1.", "Dissolve yeast in hot stock (or possib...
# 9  ["mix beef and sausage.", "preheat oven to 350...
#
#                                                 link     source  \
# 0  recipeland.com/recipe/v/vegetable-frittata-che...  Recipes1M
# 1  www.epicurious.com/recipes/food/views/grilled-...  Recipes1M
# 2  www.food.com/recipe/spiced-up-vegetable-pasta-...  Recipes1M
# 3  www.food.com/recipe/secret-ingredient-chocolat...  Recipes1M
# 4  www.food.com/recipe/chantris-poppy-seed-chicke...  Recipes1M
# 5  www.kraftrecipes.com/recipes/southwestern-rice...  Recipes1M
# 6             www.food.com/recipe/quesadillas-298819  Recipes1M
# 7  www.foodandwine.com/recipes/october-2008-roast...  Recipes1M
# 8  cookeatshare.com/recipes/mixed-grain-sour-doug...  Recipes1M
# 9   www.food.com/recipe/italian-cheeseburgers-327127  Recipes1M
#
#                                                  NER
# 0  ["eggs", "basil", "olive oil", "whole kernel c...
# 1  ["extra-virgin olive oil", "garlic", "red pepp...
# 2  ["bell pepper", "tomatoes", "eggplant", "garli...
# 3  ["butter", "butter flavor", "brown sugar", "ma...
# 4  ["chicken breasts", "cream of mushroom soup", ...
# 5  ["white rice", "baby arugula", "fresh corn ker...
# 6  ["beans", "flour tortillas", "extra virgin oli...
# 7  ["shallots", "grape tomatoes", "extra-virgin o...
# 8  ["hot stock", "baking yeast", "sour dough star...
# 9  ["ground beef", "ground hot Italian sausage", ...
# Alle SPalten ['Unnamed: 0', 'title', 'ingredients', 'directions', 'link', 'source', 'NER']

# %% [markdown]
# Tokenizer: Hugging Face Tokenizer
# -> Text wird bereinigt; Groß/Kleinschreibung
# -> Voraufteilung (Pre-Tokenization) Text wird in Leerzeichen und Satzzeichen aufgeteilt
# -> Häufige Zeichenpaare werden analysiert. Jeder Token bekommt eine ID

# %% [markdown]
# Doing: nur title; ingedients, directions und ner werden in den Tokenizer einzeln als Text eingefügt. Der Rest fällt auf Grund der irrelevanz weg.

# %%
print(df.isna().sum())
print(df.apply(type).value_counts())
print(df.head(0))
print(df.apply(type).value_counts())


df = df[['title', 'ingredients', 'directions', 'NER']]
df = df[:100]

for col in ['ingredients', 'NER']:
    df[col] = df[col].apply(lambda x: ' '.join(eval(x)))


df['combined'] = df['title'] + ' ' + df['ingredients'] + ' ' + df['directions'] + ' ' + df['NER']

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

df['tokens'] = df['combined'].apply(lambda x: tokenizer.tokenize(x))
df['input_ids'] = df['combined'].apply(lambda x: tokenizer(x)['input_ids'])

print(df.head(10))
# Out:
# Unnamed: 0     0
# title          0
# ingredients    0
# directions     0
# link           0
# source         0
# NER            0
# dtype: int64
# <class 'pandas.core.series.Series'>    7
# Name: count, dtype: int64
# Empty DataFrame
# Columns: [Unnamed: 0, title, ingredients, directions, link, source, NER]
# Index: []
# <class 'pandas.core.series.Series'>    7
# Name: count, dtype: int64
# Token indices sequence length is longer than the specified maximum sequence length for this model (618 > 512). Running this sequence through the model will result in indexing errors
#                                                title  \
# 0                     Vegetable Frittata with Cheese
# 1  Grilled Clams with Spaghetti, Prosciutto, and ...
# 2                          Spiced up Vegetable Pasta
# 3           Secret Ingredient Chocolate Chip Cookies
# 4                       Chantri's Poppy Seed Chicken
# 5                            Southwestern Rice Salad
# 6                                        Quesadillas
# 7  Roasted Tomato and Shallot Salad with Goat Cheese
# 8                Mixed Grain Sour Dough Bread Recipe
# 9                              Italian Cheeseburgers
#
#                                          ingredients  \
# 0  8 large eggs slightly beaten 1 tablespoon basi...
# 1  1/2 cup extra-virgin olive oil 4 garlic cloves...
# 2  14 cup bell pepper, finely chopped (yellow, or...
# 3  12 cup butter 12 cup butter flavor shortening ...
# 4  4 chicken breasts 1 can cream of mushroom soup...
# 5  3-3/4 qt. cooked long-grain white rice 3-3/4 q...
# 6  1 cup canned refried beans 2 large flour torti...
# 7  8 small shallots, quartered 1 1/2 cups grape t...
# 8  3 1/2 c. hot stock or possibly water 2 tbsp. b...
# 9  12 lb ground beef 12 lb ground hot Italian sau...
#
#                                           directions  \
# 0  ["In a medium bowl combine eggs and basil; set...
# 1  ["Heat oil in heavy large pot over medium-high...
# 2  ["Bring a large pot of salted water to a rolli...
# 3  ["Soften butter and shortening in microwave.",...
# 4  ["Preheat oven to 350*.", "Poach chicken until...
# 5                       ["Combine all ingredients."]
# 6  ["Preheat oven to 350 degrees.", "Spread beans...
# 7  ["Preheat the oven to 350.", "In a medium baki...
# 8  ["1.", "Dissolve yeast in hot stock (or possib...
# 9  ["mix beef and sausage.", "preheat oven to 350...
#
#                                                  NER  \
# 0  eggs basil olive oil whole kernel corn zucchin...
# 1  extra-virgin olive oil garlic red pepper Swiss...
# 2  bell pepper tomatoes eggplant garlic white win...
# 3  butter butter flavor brown sugar marshmallow c...
# 4  chicken breasts cream of mushroom soup sour cr...
# 5  white rice baby arugula fresh corn kernels shr...
# 6  beans flour tortillas extra virgin olive oil t...
# 7  shallots grape tomatoes extra-virgin olive oil...
# 8  hot stock baking yeast sour dough starter roll...
# 9  ground beef ground hot Italian sausage butter ...
#
#                                             combined  \
# 0  Vegetable Frittata with Cheese 8 large eggs sl...
# 1  Grilled Clams with Spaghetti, Prosciutto, and ...
# 2  Spiced up Vegetable Pasta 14 cup bell pepper, ...
# 3  Secret Ingredient Chocolate Chip Cookies 12 cu...
# 4  Chantri's Poppy Seed Chicken 4 chicken breasts...
# 5  Southwestern Rice Salad 3-3/4 qt. cooked long-...
# 6  Quesadillas 1 cup canned refried beans 2 large...
# 7  Roasted Tomato and Shallot Salad with Goat Che...
# 8  Mixed Grain Sour Dough Bread Recipe 3 1/2 c. h...
# 9  Italian Cheeseburgers 12 lb ground beef 12 lb ...
#
#                                               tokens  \
# 0  [vegetable, fr, ##itt, ##ata, with, cheese, 8,...
# 1  [grille, ##d, cl, ##ams, with, spaghetti, ,, p...
# 2  [spice, ##d, up, vegetable, pasta, 14, cup, be...
# 3  [secret, ingredient, chocolate, chip, cookies,...
# 4  [chant, ##ri, ', s, poppy, seed, chicken, 4, c...
# 5  [southwestern, rice, salad, 3, -, 3, /, 4, q, ...
# 6  [que, ##sa, ##di, ##llas, 1, cup, canned, ref,...
# 7  [roasted, tomato, and, shall, ##ot, salad, wit...
# 8  [mixed, grain, sour, dough, bread, recipe, 3, ...
# 9  [italian, cheese, ##burg, ##ers, 12, lb, groun...
#
#                                            input_ids
# 0  [101, 15415, 10424, 12474, 6790, 2007, 8808, 1...
# 1  [101, 26192, 2094, 18856, 13596, 2007, 26666, ...
# 2  [101, 17688, 2094, 2039, 15415, 24857, 2403, 2...
# 3  [101, 3595, 21774, 7967, 9090, 16324, 2260, 24...
# 4  [101, 16883, 3089, 1005, 1055, 19745, 6534, 79...
# 5  [101, 8772, 5785, 16521, 1017, 1011, 1017, 101...
# 6  [101, 10861, 3736, 4305, 25816, 1015, 2452, 27...
# 7  [101, 28115, 20856, 1998, 4618, 4140, 16521, 2...
# 8  [101, 3816, 8982, 14768, 23126, 7852, 17974, 1...
# 9  [101, 3059, 8808, 4645, 2545, 2260, 6053, 2598...

# %% [markdown]
# Data Sampling; Bedeutung: Aufteilung der input_ids in Fenster (Chunks) -> Tokenizer kann manximal 512 Token aufteilen -> Lösung: Aufteilung in Chunks

# %%
max_length = 512
stride = 256

all_chunks = []
all_embeddings = []
model = AutoModel.from_pretrained("bert-base-uncased")
for text in df['combined']:
    tokens = tokenizer(
        text,
        max_length=max_length,
        stride=stride,
        truncation=True,
        return_overflowing_tokens=True,
        padding="max_length",
        return_tensors="pt" 
    )
    all_chunks.extend(tokens['input_ids'])


    with torch.no_grad():
        output = model(**{k: v for k, v in tokens.items() if k != 'overflow_to_sample_mapping'})
    
    embedding = output.last_hidden_state[:, 0, :]
    all_embeddings.append(embedding)

print(f"Anzahl Chunks: {len(all_chunks)}")
print(f"Anzahl Embeddings: {len(all_embeddings)}")
print(f"Embedding Shape: {all_embeddings[0].shape}")
# Out:
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 17741.12it/s]
# BertModel LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Anzahl Chunks: 114
# Anzahl Embeddings: 100
# Embedding Shape: torch.Size([1, 768])
