# %% [markdown]
# # University Project: Large Language Models from Scratch
# **Group:** Phillip Graf, Konstantin Schmidt, Fabian Holländer
#
# ## Lab 1: Set up
#
# To set up your compute to run and train the notebooks. Please follow the instructions of the setup directory of the Book "LLMs from scratch" from the author Sebastian Raschka.
#
# Link: Abgabe\phillip\setup
#
# **TODO**
# - vor Abgabe fertig überarbeiten
